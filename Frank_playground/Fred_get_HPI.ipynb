# %%
# Populate the data in resources for all counties
# Dependencies
import requests
from dotenv import load_dotenv
import os
import pandas as pd
from bs4 import BeautifulSoup
from requests.exceptions import ConnectTimeout, ReadTimeout, RequestException

# %%
# this section of code make a request and permits up to max_retries 
def get_page(url, max_retries=3):
    retries = 0
    while retries < max_retries:
        try:
            # Attempt to make the HTTP GET request with a specified timeout
            response = requests.get(url, timeout=2)  # adding a sensible timeout
            # If the request is successful, break out of the loop
            if response.status_code == 200:
                return response.text
            if response.status_code == 404:
                return None , None
        except (ConnectTimeout, ReadTimeout) as e:
            # Print an error message showing the retry attempt
            print(f"Attempt {retries + 1} of {max_retries} failed with timeout. Retrying...")
            retries += 1
            if retries == max_retries:
                print("Max retries exceeded. Failing...")
                raise  # Re-raise the last exception after final attempt
        except RequestException as e:
            print(f"Attempt {retries + 1} failed with a request exception: {e}. Retrying...")
            retries += 1
            if retries == max_retries:
                print("Max retries exceeded with request exceptions. Failing...")
                raise
        except: 
            return None, None

    # If all retries are exhausted without a return, it indicates a failure
    print("Request failed after maximum retries.")
    return None, None

# %%
# this section of code make a request and permits up to max_retries 
def make_request_with_retries(url, max_retries=3):
    retries = 0
    while retries < max_retries:
        try:
            # Attempt to make the HTTP GET request with a specified timeout
            response = requests.get(url, timeout=2)  # adding a sensible timeout
            # If the request is successful, break out of the loop
            if response.status_code == 200:
                if response:
                    print(f"Request succeeded for {url}")
                    # Parse the HTML content
                    soup = BeautifulSoup(response.text, 'html.parser')
                    # Find the <title> tag
                    title_tag = soup.find('title')
                    # Extract the text from the <title> tag
                    title_text = title_tag.text if title_tag else None
                    # Add the title text to the list if it exists
                    if title_text:
                        # Split the string to isolate the part before the first '|'
                        main_part = title_text.split('|')[0].strip()
                        # Extract the county name; it's always followed by ", TX"
                        county = main_part.split(", TX")[0].split('for ')[-1].strip()
                        # Extract the series ID; it's always within parentheses
                        series_id = main_part.split('(')[-1].split(')')[0].strip()
                return county,series_id
            if response.status_code == 404:
                return None , None
        except (ConnectTimeout, ReadTimeout) as e:
            # Print an error message showing the retry attempt
            print(f"Attempt {retries + 1} of {max_retries} failed with timeout. Retrying...")
            retries += 1
            if retries == max_retries:
                print("Max retries exceeded. Failing...")
                raise  # Re-raise the last exception after final attempt
        except RequestException as e:
            print(f"Attempt {retries + 1} failed with a request exception: {e}. Retrying...")
            retries += 1
            if retries == max_retries:
                print("Max retries exceeded with request exceptions. Failing...")
                raise
        except: 
            return None, None

    # If all retries are exhausted without a return, it indicates a failure
    print("Request failed after maximum retries.")
    return None, None

# %%
# get  a list of all counties in dallas. this will be used to build the list of request URL's for resident population.
# https://fred.stlouisfed.org/categories/29898 this page has all counties in Dallas
def extract_readable_text(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    # Extract all paragraph texts and combine them
    text = '\n'.join(p.get_text() for p in soup.find_all('p'))
    return text
try:
    url = f'https://fred.stlouisfed.org/categories/29898'
    counties_page = get_page(url)
    print (f'this is it \n {extract_readable_text(counties_page)}')
except Exception as e:  # Catching a general exception for any other errors
    print(f"An error occurred while processing {url}: {e}")
# Out:
# this is it
#  Explore resources provided by the Research Division at the Federal Reserve Bank of St. Louis.
# Your trusted data source
# since 1991.
#
# Categories > U.S. Regional Data > States > Texas

# %%
counties = []
hpi_ids = []
for index in range(1, 520):  # Adjusted range to Python syntax
    try:
        url = f'https://fred.stlouisfed.org/series/ATNHPIUS48{index:03}A'
        county,hpi_id = make_request_with_retries(url)
        if county:
                counties.append(county)
                hpi_ids.append(hpi_id)
        else:
            print(f"Failed to retrieve the webpage for {url}.")
    except Exception as e:  # Catching a general exception for any other errors
        print(f"An error occurred while processing {url}: {e}")
# Print the list to see the result
print(f"Collected {len(counties)} HPI Counties.")
county_series_ids_df = pd.DataFrame({
    'County': counties,
    'HPI ID': hpi_ids
})
county_series_ids_df.head(10)
# Out:
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48001A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48002A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48003A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48004A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48005A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48006A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48007A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48008A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48009A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48010A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48011A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48012A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48013A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48014A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48015A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48016A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48017A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48018A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48019A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48020A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48021A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48022A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48023A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48024A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48025A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48026A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48027A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48028A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48029A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48030A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48031A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48032A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48033A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48034A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48035A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48036A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48037A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48038A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48039A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48040A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48041A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48042A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48043A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48044A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48045A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48046A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48047A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48048A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48049A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48050A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48051A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48052A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48053A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48054A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48055A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48056A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48057A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48058A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48059A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48060A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48061A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48062A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48063A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48064A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48065A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48066A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48067A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48068A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48069A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48070A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48071A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48072A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48073A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48074A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48075A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48076A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48077A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48078A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48079A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48080A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48081A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48082A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48083A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48084A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48085A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48086A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48087A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48088A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48089A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48090A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48091A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48092A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48093A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48094A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48095A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48096A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48097A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48098A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48099A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48100A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48101A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48102A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48103A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48104A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48105A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48106A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48107A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48108A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48109A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48110A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48111A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48112A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48113A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48114A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48115A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48116A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48117A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48118A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48119A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48120A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48121A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48122A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48123A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48124A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48125A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48126A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48127A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48128A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48129A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48130A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48131A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48132A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48133A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48134A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48135A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48136A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48137A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48138A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48139A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48140A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48141A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48142A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48143A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48144A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48145A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48146A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48147A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48148A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48149A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48150A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48151A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48152A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48153A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48154A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48155A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48156A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48157A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48158A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48159A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48160A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48161A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48162A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48163A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48164A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48165A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48166A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48167A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48168A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48169A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48170A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48171A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48172A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48173A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48174A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48175A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48176A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48177A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48178A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48179A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48180A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48181A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48182A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48183A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48184A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48185A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48186A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48187A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48188A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48189A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48190A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48191A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48192A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48193A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48194A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48195A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48196A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48197A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48198A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48199A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48200A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48201A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48202A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48203A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48204A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48205A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48206A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48207A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48208A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48209A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48210A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48211A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48212A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48213A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48214A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48215A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48216A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48217A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48218A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48219A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48220A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48221A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48222A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48223A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48224A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48225A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48226A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48227A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48228A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48229A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48230A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48231A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48232A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48233A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48234A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48235A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48236A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48237A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48238A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48239A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48240A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48241A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48242A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48243A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48244A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48245A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48246A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48247A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48248A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48249A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48250A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48251A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48252A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48253A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48254A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48255A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48256A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48257A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48258A.
# Request succeeded for https://fred.stlouisfed.org/series/ATNHPIUS48259A
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48260A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48261A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48262A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS48263A.
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/ATNHPIUS