# %%
# Populate the data in resources for all counties
# Dependencies
import requests
from dotenv import load_dotenv
import os
import pandas as pd
from bs4 import BeautifulSoup
from requests.exceptions import ConnectTimeout, ReadTimeout, RequestException
import subprocess

# %%
# this section of code make a request and permits up to max_retries 
def get_page(url, max_retries=3):
    retries = 0
    while retries < max_retries:
        try:
            # Attempt to make the HTTP GET request with a specified timeout
            response = requests.get(url, timeout=2)  # adding a sensible timeout
            # If the request is successful, break out of the loop
            if response.status_code == 200:
                return response.text
            if response.status_code == 404:
                return None , None
        except (ConnectTimeout, ReadTimeout) as e:
            # Print an error message showing the retry attempt
            print(f"Attempt {retries + 1} of {max_retries} failed with timeout. Retrying...")
            retries += 1
            if retries == max_retries:
                print("Max retries exceeded. Failing...")
                raise  # Re-raise the last exception after final attempt
        except RequestException as e:
            print(f"Attempt {retries + 1} failed with a request exception: {e}. Retrying...")
            retries += 1
            if retries == max_retries:
                print("Max retries exceeded with request exceptions. Failing...")
                raise
        except: 
            return None, None

    # If all retries are exhausted without a return, it indicates a failure
    print("Request failed after maximum retries.")
    return None, None

# %%
# this section of code make a request and permits up to max_retries 
def make_request_with_retries(url, max_retries=3):
    retries = 0
    while retries < max_retries:
        try:
            # Attempt to make the HTTP GET request with a specified timeout
            response = requests.get(url, timeout=2)  # adding a sensible timeout
            # If the request is successful, break out of the loop
            if response.status_code == 200:
                if response:
                    print(f"Request succeeded for {url}")
                    # Parse the HTML content
                    soup = BeautifulSoup(response.text, 'html.parser')
                    # Find the <title> tag
                    title_tag = soup.find('title')
                    # Extract the text from the <title> tag
                    title_text = title_tag.text if title_tag else None
                    # Add the title text to the list if it exists
                    if title_text:
                        # Split the string to isolate the part before the first '|'
                        main_part = title_text.split('|')[0].strip()
                        # Extract the county name; it's always followed by ", TX"
                        county = main_part.split(", TX")[0].split('for ')[-1].strip()
                        # Extract the series ID; it's always within parentheses
                        series_id = main_part.split('(')[-1].split(')')[0].strip()
                return county,series_id
            if response.status_code == 404:
                return None , None
        except (ConnectTimeout, ReadTimeout) as e:
            # Print an error message showing the retry attempt
            print(f"Attempt {retries + 1} of {max_retries} failed with timeout. Retrying...")
            retries += 1
            if retries == max_retries:
                print("Max retries exceeded. Failing...")
                raise  # Re-raise the last exception after final attempt
        except RequestException as e:
            print(f"Attempt {retries + 1} failed with a request exception: {e}. Retrying...")
            retries += 1
            if retries == max_retries:
                print("Max retries exceeded with request exceptions. Failing...")
                raise
        except: 
            return None, None

    # If all retries are exhausted without a return, it indicates a failure
    print("Request failed after maximum retries.")
    return None, None

# %%
'''# get  a list of all counties in dallas. this will be used to build the list of request URL's for resident population.
# https://fred.stlouisfed.org/categories/29898 this page has all counties in Dallas
def extract_readable_text(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    # Extract all paragraph texts and combine them
    text = '\n'.join(p.get_text() for p in soup.find_all('p'))
    return text
try:
    url = f'https://fred.stlouisfed.org/categories/29898'
    counties_page = get_page(url)
    print (f'this is it \n {extract_readable_text(counties_page)}')
except Exception as e:  # Catching a general exception for any other errors
    print(f"An error occurred while processing {url}: {e}")
    '''
# Out:
# '# get  a list of all counties in dallas. this will be used to build the list of request URL\'s for resident population.\n# https://fred.stlouisfed.org/categories/29898 this page has all counties in Dallas\ndef extract_readable_text(html_content):\n    soup = BeautifulSoup(html_content, \'html.parser\')\n    # Extract all paragraph texts and combine them\n    text = \'\n\'.join(p.get_text() for p in soup.find_all(\'p\'))\n    return text\ntry:\n    url = f\'https://fred.stlouisfed.org/categories/29898\'\n    counties_page = get_page(url)\n    print (f\'this is it \n {extract_readable_text(counties_page)}\')\nexcept Exception as e:  # Catching a general exception for any other errors\n    print(f"An error occurred while processing {url}: {e}")\n    '

# %%
counties = []
hpi_ids = []
for index in range(1, 520):  # Adjusted range to Python syntax
    try:
        url = f'https://fred.stlouisfed.org/series/MHITX48{index:03}A052NCEN' # MHITX48085A052NCEN
        county,hpi_id = make_request_with_retries(url)
        if county:
                counties.append(county)
                hpi_ids.append(hpi_id)
        else:
            print(f"Failed to retrieve the webpage for {url}.")
    except Exception as e:  # Catching a general exception for any other errors
        print(f"An error occurred while processing {url}: {e}")
# Print the list to see the result
print(f"Collected {len(counties)} HPI Counties.")
county_series_ids_df = pd.DataFrame({
    'County': counties,
    'HHI ID': hpi_ids
})
county_series_ids_df.head(10)
# Out:
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48001A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48002A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48003A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48004A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48005A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48006A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48007A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48008A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48009A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48010A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48011A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48012A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48013A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48014A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48015A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48016A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48017A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48018A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48019A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48020A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48021A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48022A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48023A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48024A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48025A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48026A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48027A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48028A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48029A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48030A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48031A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48032A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48033A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48034A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48035A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48036A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48037A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48038A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48039A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48040A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48041A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48042A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48043A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48044A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48045A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48046A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48047A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48048A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48049A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48050A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48051A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48052A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48053A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48054A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48055A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48056A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48057A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48058A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48059A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48060A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48061A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48062A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48063A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48064A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48065A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48066A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48067A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48068A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48069A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48070A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48071A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48072A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48073A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48074A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48075A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48076A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48077A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48078A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48079A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48080A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48081A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48082A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48083A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48084A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48085A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48086A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48087A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48088A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48089A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48090A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48091A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48092A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48093A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48094A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48095A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48096A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48097A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48098A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48099A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48100A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48101A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48102A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48103A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48104A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48105A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48106A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48107A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48108A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48109A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48110A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48111A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48112A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48113A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48114A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48115A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48116A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48117A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48118A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48119A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48120A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48121A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48122A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48123A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48124A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48125A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48126A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48127A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48128A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48129A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48130A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48131A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48132A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48133A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48134A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48135A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48136A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48137A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48138A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48139A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48140A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48141A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48142A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48143A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48144A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48145A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48146A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48147A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48148A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48149A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48150A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48151A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48152A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48153A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48154A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48155A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48156A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48157A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48158A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48159A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48160A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48161A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48162A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48163A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48164A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48165A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48166A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48167A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48168A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48169A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48170A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48171A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48172A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48173A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48174A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48175A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48176A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48177A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48178A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48179A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48180A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48181A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48182A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48183A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48184A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48185A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48186A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48187A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48188A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48189A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48190A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48191A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48192A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48193A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48194A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48195A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48196A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48197A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48198A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48199A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48200A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48201A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48202A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48203A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48204A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48205A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48206A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48207A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48208A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48209A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48210A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48211A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48212A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48213A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48214A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48215A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48216A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48217A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48218A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48219A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48220A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48221A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48222A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48223A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48224A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48225A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48226A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48227A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48228A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48229A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48230A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48231A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48232A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48233A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48234A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48235A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48236A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48237A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48238A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48239A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48240A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48241A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48242A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48243A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48244A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48245A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48246A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48247A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48248A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48249A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48250A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX48251A052NCEN
# Failed to retrieve the webpage for https://fred.stlouisfed.org/series/MHITX48252A052NCEN.
# Request succeeded for https://fred.stlouisfed.org/series/MHITX